# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing CSVs

# %%
airports_ex = pd.read_csv('airports-extended.csv')
routes = pd.read_csv('routes.csv')
airlines = pd.read_csv('airlines.csv')

# %% [markdown]
# ## Preprocessing airports data

# %%
airports_ex.head()
# Out:
#    1                               Goroka Airport        Goroka  \
# 0  2                               Madang Airport        Madang
# 1  3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 2  4                               Nadzab Airport        Nadzab
# 3  5  Port Moresby Jacksons International Airport  Port Moresby
# 4  6                  Wewak International Airport         Wewak
#
#    Papua New Guinea  GKA  AYGA  -6.08168983459  145.391998291  5282    10  U  \
# 0  Papua New Guinea  MAG  AYMD       -5.207080     145.789001    20  10.0  U
# 1  Papua New Guinea  HGU  AYMH       -5.826790     144.296005  5388  10.0  U
# 2  Papua New Guinea  LAE  AYNZ       -6.569803     146.725977   239  10.0  U
# 3  Papua New Guinea  POM  AYPY       -9.443380     147.220001   146  10.0  U
# 4  Papua New Guinea  WWK  AYWK       -3.583830     143.669006    19  10.0  U
#
#    Pacific/Port_Moresby  airport  OurAirports
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airports_ex.columns = ['Airport_ID', 'Airport_Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz database time zone','Type', 'Source']

# %%
airports_ex.head()
# Out:
#    Airport_ID                                 Airport_Name          City  \
# 0           2                               Madang Airport        Madang
# 1           3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 2           4                               Nadzab Airport        Nadzab
# 3           5  Port Moresby Jacksons International Airport  Port Moresby
# 4           6                  Wewak International Airport         Wewak
#
#             Country IATA  ICAO  Latitude   Longitude  Altitude  Timezone DST  \
# 0  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 1  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 2  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 3  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
# 4  Papua New Guinea  WWK  AYWK -3.583830  143.669006        19      10.0   U
#
#   Tz database time zone     Type       Source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airports_ex['Type'].value_counts()
# Out:
# airport    8263
# station    1332
# unknown    1320
# port        101
# Name: Type, dtype: int64

# %%
airports =  airports_ex.drop(airports_ex.loc[airports_ex['Type'] != 'airport' ].index)

# %%
airports['Type'].value_counts()
# Out:
# airport    8263
# Name: Type, dtype: int64

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8263 entries, 0 to 12665
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Airport_ID             8263 non-null   int64
#  1   Airport_Name           8263 non-null   object
#  2   City                   8214 non-null   object
#  3   Country                8263 non-null   object
#  4   IATA                   6471 non-null   object
#  5   ICAO                   7754 non-null   object
#  6   Latitude               8263 non-null   float64
#  7   Longitude              8263 non-null   float64
#  8   Altitude               8263 non-null   int64
#  9   Timezone               7910 non-null   float64
#  10  DST                    7910 non-null   object
#  11  Tz database time zone  7147 non-null   object
#  12  Type                   8263 non-null   object
#  13  Source                 8263 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 968.3+ KB

# %% [markdown]
# ## VIS_1: Top 20 COuntries with most number of Airports

# %%
airports['Country'].value_counts()
# Out:
# United States    1752
# Canada            459
# Australia         343
# Russia            271
# Brazil            269
#                  ...
# Isle of Man         1
# Jersey              1
# West Bank           1
# Gambia              1
# Wake Island         1
# Name: Country, Length: 237, dtype: int64

# %%
plot_df1 = (
    airports['Country'].value_counts()
        .head(20)
        .rename_axis('Country')
        .reset_index(name='no_of_airports')
)
plot_df1
# Out:
#            Country  no_of_airports
# 0    United States            1752
# 1           Canada             459
# 2        Australia             343
# 3           Russia             271
# 4           Brazil             269
# 5          Germany             257
# 6            China             251
# 7           France             221
# 8   United Kingdom             177
# 9        Indonesia             158
# 10           India             153
# 11           Japan             131
# 12    South Africa             103
# 13       Argentina              96
# 14          Mexico              88
# 15           Italy              86
# 16            Iran              83
# 17          Sweden              80
# 18          Turkey              78
# 19        Colombia              78

# %%
x_labels = plot_df1['Country']
fig = plot_df1.plot(kind='bar')
plt.title('Top 20 COuntries with most number of Airports')
fig.set_xticklabels(x_labels)
fig.bar_label(fig.containers[0], label_type='edge')
# Out:
# [Text(0, 0, '1752'),
#  Text(0, 0, '459'),
#  Text(0, 0, '343'),
#  Text(0, 0, '271'),
#  Text(0, 0, '269'),
#  Text(0, 0, '257'),
#  Text(0, 0, '251'),
#  Text(0, 0, '221'),
#  Text(0, 0, '177'),
#  Text(0, 0, '158'),
#  Text(0, 0, '153'),
#  Text(0, 0, '131'),
#  Text(0, 0, '103'),
#  Text(0, 0, '96'),
#  Text(0, 0, '88'),
#  Text(0, 0, '86'),
#  Text(0, 0, '83'),
#  Text(0, 0, '80'),
#  Text(0, 0, '78'),
#  Text(0, 0, '78')]

# %%
plot_df1 = (
    airports['Country'].value_counts()
        .rename_axis('Country')
        .reset_index(name='no_of_airports')
)
plot_df1
# Out:
#            Country  no_of_airports
# 0    United States            1752
# 1           Canada             459
# 2        Australia             343
# 3           Russia             271
# 4           Brazil             269
# ..             ...             ...
# 232    Isle of Man               1
# 233         Jersey               1
# 234      West Bank               1
# 235         Gambia               1
# 236    Wake Island               1
#
# [237 rows x 2 columns]

# %%
plot_df2 = plot_df1[plot_df1.no_of_airports <= 1]
#np.array()

# %%
plt.figure(figsize = (50,5))
plt.bar(plot_df2['Country'], plot_df2['no_of_airports'])
# Out:
# <BarContainer object of 27 artists>

# %% [markdown]
# ## Preprocessing Routes data

# %%
routes.head()
# Out:
#    2B  410  AER  2965  KZN  2990 Unnamed: 6  0  CR2
# 0  2B  410  ASF  2966  KZN  2990        NaN  0  CR2
# 1  2B  410  ASF  2966  MRV  2962        NaN  0  CR2
# 2  2B  410  CEK  2968  KZN  2990        NaN  0  CR2
# 3  2B  410  CEK  2968  OVB  4078        NaN  0  CR2
# 4  2B  410  DME  4029  KZN  2990        NaN  0  CR2

# %%
routes.columns = ['Airline_IATA', 'Airline_ID', 'Source_airport', 'Source_airport_ID', 'Destination_airport', 'Destination_airport_ID', 'Codeshare', 'Stops', 'Equipment']

# %%
routes
# Out:
#       Airline_IATA Airline_ID Source_airport Source_airport_ID  \
# 0               2B        410            ASF              2966
# 1               2B        410            ASF              2966
# 2               2B        410            CEK              2968
# 3               2B        410            CEK              2968
# 4               2B        410            DME              4029
# ...            ...        ...            ...               ...
# 67657           ZL       4178            WYA              6334
# 67658           ZM      19016            DME              4029
# 67659           ZM      19016            FRU              2912
# 67660           ZM      19016            FRU              2912
# 67661           ZM      19016            OSS              2913
#
#       Destination_airport Destination_airport_ID Codeshare  Stops Equipment
# 0                     KZN                   2990       NaN      0       CR2
# 1                     MRV                   2962       NaN      0       CR2
# 2                     KZN                   2990       NaN      0       CR2
# 3                     OVB                   4078       NaN      0       CR2
# 4                     KZN                   2990       NaN      0       CR2
# ...                   ...                    ...       ...    ...       ...
# 67657                 ADL                   3341       NaN      0       SF3
# 67658                 FRU                   2912       NaN      0       734
# 67659                 DME                   4029       NaN      0       734
# 67660                 OSS                   2913       NaN      0       734
# 67661                 FRU                   2912       NaN      0       734
#
# [67662 rows x 9 columns]

# %%
routes.isnull().sum()
# Out:
# Airline_IATA                  0
# Airline_ID                    0
# Source_airport                0
# Source_airport_ID             0
# Destination_airport           0
# Destination_airport_ID        0
# Codeshare                 53065
# Stops                         0
# Equipment                    18
# dtype: int64

# %%
routes.drop(['Codeshare'], axis=1,inplace = True)

# %% [markdown]
# ## Preprocessing Airline data

# %%
airlines.head()
# Out:
#    -1                                       Unknown  \N    -  N/A     \N.1  \
# 0   1                                Private flight  \N    -  NaN      NaN
# 1   2                                   135 Airways  \N  NaN  GNL  GENERAL
# 2   3                                 1Time Airline  \N   1T  RNX  NEXTIME
# 3   4  2 Sqn No 1 Elementary Flying Training School  \N  NaN  WYT      NaN
# 4   5                               213 Flight Unit  \N  NaN  TFU      NaN
#
#              \N.2  Y
# 0             NaN  Y
# 1   United States  N
# 2    South Africa  Y
# 3  United Kingdom  N
# 4          Russia  N

# %%
airlines.columns = ['Airline_ID', 'Airline_Name', 'Airline_Alias', 'Airline_IATA', 'Airline_ICAO', 'Callsign', 'Airline_Country', 'Active']

# %%
airlines
# Out:
#       Airline_ID                                  Airline_Name  \
# 0              1                                Private flight
# 1              2                                   135 Airways
# 2              3                                 1Time Airline
# 3              4  2 Sqn No 1 Elementary Flying Training School
# 4              5                               213 Flight Unit
# ...          ...                                           ...
# 6156       21248                                   GX Airlines
# 6157       21251                        Lynx Aviation (L3/SSX)
# 6158       21268                               Jetgo Australia
# 6159       21270                                  Air Carnival
# 6160       21317                                 Svyaz Rossiya
#
#           Airline_Alias Airline_IATA Airline_ICAO         Callsign  \
# 0                    \N            -          NaN              NaN
# 1                    \N          NaN          GNL          GENERAL
# 2                    \N           1T          RNX          NEXTIME
# 3                    \N          NaN          WYT              NaN
# 4                    \N          NaN          TFU              NaN
# ...                 ...          ...          ...              ...
# 6156                NaN          NaN          CBG            SPRAY
# 6157                NaN          NaN          SSX           Shasta
# 6158                NaN           JG           \N              NaN
# 6159                NaN           2S           \N              NaN
# 6160  Russian Commuter            7R          SJM  RussianConnecty
#
#      Airline_Country Active
# 0                NaN      Y
# 1      United States      N
# 2       South Africa      Y
# 3     United Kingdom      N
# 4             Russia      N
# ...              ...    ...
# 6156           China      Y
# 6157   United States      N
# 6158       Australia      Y
# 6159           India      Y
# 6160          Russia      Y
#
# [6161 rows x 8 columns]

# %%
airlines.isnull().sum()
# Out:
# Airline_ID            0
# Airline_Name          0
# Airline_Alias       506
# Airline_IATA       4627
# Airline_ICAO         86
# Callsign            808
# Airline_Country      15
# Active                0
# dtype: int64

# %%
airlines_df = airlines[['Airline_Name', 'Airline_IATA']]
airlines_df.head()
# Out:
#                                    Airline_Name Airline_IATA
# 0                                Private flight            -
# 1                                   135 Airways          NaN
# 2                                 1Time Airline           1T
# 3  2 Sqn No 1 Elementary Flying Training School          NaN
# 4                               213 Flight Unit          NaN

# %%
airline_routes = pd.merge(left = airlines_df, 
                 right = routes,
                 how= 'right',
                 left_on='Airline_IATA',
                 right_on='Airline_IATA',
                 suffixes=('_x', '_y'))

# %%
airline_routes
# Out:
#            Airline_Name Airline_IATA Airline_ID Source_airport  \
# 0            Aerocondor           2B        410            ASF
# 1            Aerocondor           2B        410            ASF
# 2            Aerocondor           2B        410            CEK
# 3            Aerocondor           2B        410            CEK
# 4            Aerocondor           2B        410            DME
# ...                 ...          ...        ...            ...
# 78215  Regional Express           ZL       4178            WYA
# 78216        Apache Air           ZM      19016            DME
# 78217        Apache Air           ZM      19016            FRU
# 78218        Apache Air           ZM      19016            FRU
# 78219        Apache Air           ZM      19016            OSS
#
#       Source_airport_ID Destination_airport Destination_airport_ID  Stops  \
# 0                  2966                 KZN                   2990      0
# 1                  2966                 MRV                   2962      0
# 2                  2968                 KZN                   2990      0
# 3                  2968                 OVB                   4078      0
# 4                  4029                 KZN                   2990      0
# ...                 ...                 ...                    ...    ...
# 78215              6334                 ADL                   3341      0
# 78216              4029                 FRU                   2912      0
# 78217              2912                 DME                   4029      0
# 78218              2912                 OSS                   2913      0
# 78219              2913                 FRU                   2912      0
#
#       Equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ...         ...
# 78215       SF3
# 78216       734
# 78217       734
# 78218       734
# 78219       734
#
# [78220 rows x 9 columns]

# %%
airline_routes.isnull().sum()
# Out:
# Airline_Name              852
# Airline_IATA                0
# Airline_ID                  0
# Source_airport              0
# Source_airport_ID           0
# Destination_airport         0
# Destination_airport_ID      0
# Stops                       0
# Equipment                  19
# dtype: int64

# %%
airports.columns
# Out:
# Index(['Airport_ID', 'Airport_Name', 'City', 'Country', 'IATA', 'ICAO',
#        'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST',
#        'Tz database time zone', 'Type', 'Source'],
#       dtype='object')

# %%
airports_info =  airports[['IATA','Airport_Name', 'City', 'Country','Latitude', 'Longitude']]

# %%
airports_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8263 entries, 0 to 12665
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IATA          6471 non-null   object
#  1   Airport_Name  8263 non-null   object
#  2   City          8214 non-null   object
#  3   Country       8263 non-null   object
#  4   Latitude      8263 non-null   float64
#  5   Longitude     8263 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 451.9+ KB

# %%
airline_routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78220 entries, 0 to 78219
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Airline_Name            77368 non-null  object
#  1   Airline_IATA            78220 non-null  object
#  2   Airline_ID              78220 non-null  object
#  3   Source_airport          78220 non-null  object
#  4   Source_airport_ID       78220 non-null  object
#  5   Destination_airport     78220 non-null  object
#  6   Destination_airport_ID  78220 non-null  object
#  7   Stops                   78220 non-null  int64
#  8   Equipment               78201 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.0+ MB

# %%
airline_routes.isnull().sum()
# Out:
# Airline_Name              852
# Airline_IATA                0
# Airline_ID                  0
# Source_airport              0
# Source_airport_ID           0
# Destination_airport         0
# Destination_airport_ID      0
# Stops                       0
# Equipment                  19
# dtype: int64

# %%
airline_routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78220 entries, 0 to 78219
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Airline_Name            77368 non-null  object
#  1   Airline_IATA            78220 non-null  object
#  2   Airline_ID              78220 non-null  object
#  3   Source_airport          78220 non-null  object
#  4   Source_airport_ID       78220 non-null  object
#  5   Destination_airport     78220 non-null  object
#  6   Destination_airport_ID  78220 non-null  object
#  7   Stops                   78220 non-null  int64
#  8   Equipment               78201 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.0+ MB

# %%
airline_routes1 = pd.merge(left = airports_info, 
                 right = airline_routes,
                 how= 'right',
                 left_on='IATA',
                 right_on='Source_airport',
                 suffixes=('_x', '_y'))

# %%
airline_routes1
# Out:
#       IATA                      Airport_Name         City     Country  \
# 0      ASF                 Astrakhan Airport    Astrakhan      Russia
# 1      ASF                 Astrakhan Airport    Astrakhan      Russia
# 2      CEK     Chelyabinsk Balandino Airport  Chelyabinsk      Russia
# 3      CEK     Chelyabinsk Balandino Airport  Chelyabinsk      Russia
# 4      DME  Domodedovo International Airport       Moscow      Russia
# ...    ...                               ...          ...         ...
# 78215  WYA                   Whyalla Airport      Whyalla   Australia
# 78216  DME  Domodedovo International Airport       Moscow      Russia
# 78217  FRU       Manas International Airport      Bishkek  Kyrgyzstan
# 78218  FRU       Manas International Airport      Bishkek  Kyrgyzstan
# 78219  OSS                       Osh Airport          Osh  Kyrgyzstan
#
#         Latitude   Longitude      Airline_Name Airline_IATA Airline_ID  \
# 0      46.283298   48.006302        Aerocondor           2B        410
# 1      46.283298   48.006302        Aerocondor           2B        410
# 2      55.305801   61.503300        Aerocondor           2B        410
# 3      55.305801   61.503300        Aerocondor           2B        410
# 4      55.408798   37.906300        Aerocondor           2B        410
# ...          ...         ...               ...          ...        ...
# 78215 -33.058899  137.514008  Regional Express           ZL       4178
# 78216  55.408798   37.906300        Apache Air           ZM      19016
# 78217  43.061298   74.477600        Apache Air           ZM      19016
# 78218  43.061298   74.477600        Apache Air           ZM      19016
# 78219  40.609001   72.793297        Apache Air           ZM      19016
#
#       Source_airport Source_airport_ID Destination_airport  \
# 0                ASF              2966                 KZN
# 1                ASF              2966                 MRV
# 2                CEK              2968                 KZN
# 3                CEK              2968                 OVB
# 4                DME              4029                 KZN
# ...              ...               ...                 ...
# 78215            WYA              6334                 ADL
# 78216            DME              4029                 FRU
# 78217            FRU              2912                 DME
# 78218            FRU              2912                 OSS
# 78219            OSS              2913                 FRU
#
#       Destination_airport_ID  Stops Equipment
# 0                       2990      0       CR2
# 1                       2962      0       CR2
# 2                       2990      0       CR2
# 3                       4078      0       CR2
# 4                       2990      0       CR2
# ...                      ...    ...       ...
# 78215                   3341      0       SF3
# 78216                   2912      0       734
# 78217                   4029      0       734
# 78218                   2913      0       734
# 78219                   2912      0       734
#
# [78220 rows x 15 columns]

# %%
airline_routes2 = pd.merge(left = airports_info, 
                 right = airline_routes1,
                 how= 'right',
                 left_on='IATA',
                 right_on='Destination_airport',
                 suffixes=('_d', '_s'))

# %%
airline_routes2
# Out:
#       IATA_d                    Airport_Name_d           City_d   Country_d  \
# 0        KZN       Kazan International Airport            Kazan      Russia
# 1        MRV          Mineralnyye Vody Airport  Mineralnye Vody      Russia
# 2        KZN       Kazan International Airport            Kazan      Russia
# 3        OVB                Tolmachevo Airport      Novosibirsk      Russia
# 4        KZN       Kazan International Airport            Kazan      Russia
# ...      ...                               ...              ...         ...
# 78215    ADL    Adelaide International Airport         Adelaide   Australia
# 78216    FRU       Manas International Airport          Bishkek  Kyrgyzstan
# 78217    DME  Domodedovo International Airport           Moscow      Russia
# 78218    OSS                       Osh Airport              Osh  Kyrgyzstan
# 78219    FRU       Manas International Airport          Bishkek  Kyrgyzstan
#
#        Latitude_d  Longitude_d IATA_s                    Airport_Name_s  \
# 0       55.606201    49.278702    ASF                 Astrakhan Airport
# 1       44.225101    43.081902    ASF                 Astrakhan Airport
# 2       55.606201    49.278702    CEK     Chelyabinsk Balandino Airport
# 3       55.012600    82.650703    CEK     Chelyabinsk Balandino Airport
# 4       55.606201    49.278702    DME  Domodedovo International Airport
# ...           ...          ...    ...                               ...
# 78215  -34.945000   138.531006    WYA                   Whyalla Airport
# 78216   43.061298    74.477600    DME  Domodedovo International Airport
# 78217   55.408798    37.906300    FRU       Manas International Airport
# 78218   40.609001    72.793297    FRU       Manas International Airport
# 78219   43.061298    74.477600    OSS                       Osh Airport
#
#             City_s   Country_s  ...  Longitude_s      Airline_Name  \
# 0        Astrakhan      Russia  ...    48.006302        Aerocondor
# 1        Astrakhan      Russia  ...    48.006302        Aerocondor
# 2      Chelyabinsk      Russia  ...    61.503300        Aerocondor
# 3      Chelyabinsk      Russia  ...    61.503300        Aerocondor
# 4           Moscow      Russia  ...    37.906300        Aerocondor
# ...            ...         ...  ...          ...               ...
# 78215      Whyalla   Australia  ...   137.514008  Regional Express
# 78216       Moscow      Russia  ...    37.906300        Apache Air
# 78217      Bishkek  Kyrgyzstan  ...    74.477600        Apache Air
# 78218      Bishkek  Kyrgyzstan  ...    74.477600        Apache Air
# 78219          Osh  Kyrgyzstan  ...    72.793297        Apache Air
#
#       Airline_IATA Airline_ID Source_airport Source_airport_ID  \
# 0               2B        410            ASF              2966
# 1               2B        410            ASF              2966
# 2               2B        410            CEK              2968
# 3               2B        410            CEK              2968
# 4               2B        410            DME              4029
# ...            ...        ...            ...               ...
# 78215           ZL       4178            WYA              6334
# 78216           ZM      19016            DME              4029
# 78217           ZM      19016            FRU              2912
# 78218           ZM      19016            FRU              2912
# 78219           ZM      19016            OSS              2913
#
#       Destination_airport Destination_airport_ID Stops  Equipment
# 0                     KZN                   2990     0        CR2
# 1                     MRV                   2962     0        CR2
# 2                     KZN                   2990     0        CR2
# 3                     OVB                   4078     0        CR2
# 4                     KZN                   2990     0        CR2
# ...                   ...                    ...   ...        ...
# 78215                 ADL                   3341     0        SF3
# 78216                 FRU                   2912     0        734
# 78217                 DME                   4029     0        734
# 78218                 OSS                   2913     0        734
# 78219                 FRU                   2912     0        734
#
# [78220 rows x 21 columns]

# %%
airline_routes2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78220 entries, 0 to 78219
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IATA_d                  77957 non-null  object
#  1   Airport_Name_d          77957 non-null  object
#  2   City_d                  77955 non-null  object
#  3   Country_d               77957 non-null  object
#  4   Latitude_d              77957 non-null  float64
#  5   Longitude_d             77957 non-null  float64
#  6   IATA_s                  77965 non-null  object
#  7   Airport_Name_s          77965 non-null  object
#  8   City_s                  77963 non-null  object
#  9   Country_s               77965 non-null  object
#  10  Latitude_s              77965 non-null  float64
#  11  Longitude_s             77965 non-null  float64
#  12  Airline_Name            77368 non-null  object
#  13  Airline_IATA            78220 non-null  object
#  14  Airline_ID              78220 non-null  object
#  15  Source_airport          78220 non-null  object
#  16  Source_airport_ID       78220 non-null  object
#  17  Destination_airport     78220 non-null  object
#  18  Destination_airport_ID  78220 non-null  object
#  19  Stops                   78220 non-null  int64
#  20  Equipment               78201 non-null  object
# dtypes: float64(4), int64(1), object(16)
# memory usage: 13.1+ MB

# %% [markdown]
# ### Dropping unnceesaary columns to create final routes dataset

# %%
final_routes = airline_routes2[['Airline_Name','Airline_IATA',
                                'Source_airport','Airport_Name_s','City_s','Country_s','Latitude_s','Longitude_s',
                                'Destination_airport','Airport_Name_d','City_d','Country_d','Latitude_d','Longitude_d','Equipment']]

# %%
final_routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78220 entries, 0 to 78219
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Airline_Name         77368 non-null  object
#  1   Airline_IATA         78220 non-null  object
#  2   Source_airport       78220 non-null  object
#  3   Airport_Name_s       77965 non-null  object
#  4   City_s               77963 non-null  object
#  5   Country_s            77965 non-null  object
#  6   Latitude_s           77965 non-null  float64
#  7   Longitude_s          77965 non-null  float64
#  8   Destination_airport  78220 non-null  object
#  9   Airport_Name_d       77957 non-null  object
#  10  City_d               77955 non-null  object
#  11  Country_d            77957 non-null  object
#  12  Latitude_d           77957 non-null  float64
#  13  Longitude_d          77957 non-null  float64
#  14  Equipment            78201 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 9.5+ MB

# %%
final_routes.isnull().sum()
# Out:
# Airline_Name           852
# Airline_IATA             0
# Source_airport           0
# Airport_Name_s         255
# City_s                 257
# Country_s              255
# Latitude_s             255
# Longitude_s            255
# Destination_airport      0
# Airport_Name_d         263
# City_d                 265
# Country_d              263
# Latitude_d             263
# Longitude_d            263
# Equipment               19
# dtype: int64

# %%
final_routes.to_csv('final_routes.csv')

# %%
final_routes.head()
# Out:
#   Airline_Name Airline_IATA Source_airport                    Airport_Name_s  \
# 0   Aerocondor           2B            ASF                 Astrakhan Airport
# 1   Aerocondor           2B            ASF                 Astrakhan Airport
# 2   Aerocondor           2B            CEK     Chelyabinsk Balandino Airport
# 3   Aerocondor           2B            CEK     Chelyabinsk Balandino Airport
# 4   Aerocondor           2B            DME  Domodedovo International Airport
#
#         City_s Country_s  Latitude_s  Longitude_s Destination_airport  \
# 0    Astrakhan    Russia   46.283298    48.006302                 KZN
# 1    Astrakhan    Russia   46.283298    48.006302                 MRV
# 2  Chelyabinsk    Russia   55.305801    61.503300                 KZN
# 3  Chelyabinsk    Russia   55.305801    61.503300                 OVB
# 4       Moscow    Russia   55.408798    37.906300                 KZN
#
#                 Airport_Name_d           City_d Country_d  Latitude_d  \
# 0  Kazan International Airport            Kazan    Russia   55.606201
# 1     Mineralnyye Vody Airport  Mineralnye Vody    Russia   44.225101
# 2  Kazan International Airport            Kazan    Russia   55.606201
# 3           Tolmachevo Airport      Novosibirsk    Russia   55.012600
# 4  Kazan International Airport            Kazan    Russia   55.606201
#
#    Longitude_d Equipment
# 0    49.278702       CR2
# 1    43.081902       CR2
# 2    49.278702       CR2
# 3    82.650703       CR2
# 4    49.278702       CR2

# %% [markdown]
# ## VIS_2: Top 10 AIrlines with most routes

# %%
plot_df = (
    final_routes['Airline_Name'].value_counts()
        .head(10)
        .rename_axis('Airline_Name')
        .reset_index(name='no_of_routes')
)
plt.figure(figsize=(14,7))
y=  final_routes['Airline_Name'].value_counts().head(10)
mylabels = plot_df['Airline_Name']

plt.title('Top 10 AIrlines with most routes', fontsize=25)

pie = plt.pie(y,autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.legend( loc = 'right', labels=mylabels)
plt.show()

# %% [markdown]
# ## VIS_2: Top 10 Airports with maximum connectivity

# %%
plot_df = (
    final_routes['Source_airport'].value_counts()
        .rename_axis('Airport_Name_s')
        .reset_index(name='no_of_flights_o')
)
plot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3409 entries, 0 to 3408
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airport_Name_s   3409 non-null   object
#  1   no_of_flights_o  3409 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 53.4+ KB

# %%
plot_df1 = (
    final_routes['Destination_airport'].value_counts()
        .rename_axis('Airport_Name_d')
        .reset_index(name='no_of_flights_i')
)
plot_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3418 entries, 0 to 3417
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airport_Name_d   3418 non-null   object
#  1   no_of_flights_i  3418 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 53.5+ KB

# %%
plot_df2= pd.merge(left = plot_df, 
                 right = plot_df1,
                 how= 'outer',
                 left_on='Airport_Name_s',
                 right_on='Airport_Name_d',
                 suffixes=('_x', '_y'))
plot_df2 = plot_df2.head(10)
plot_df2.drop(['Airport_Name_d'], axis=1, inplace = True)
plot_df2
# Out:
#   Airport_Name_s  no_of_flights_o  no_of_flights_i
# 0            ATL            938.0            934.0
# 1            FRA            680.0            673.0
# 2            CDG            589.0            580.0
# 3            ORD            570.0            561.0
# 4            PEK            561.0            560.0
# 5            LHR            552.0            549.0
# 6            SIN            530.0            536.0
# 7            LGW            529.0            521.0
# 8            MUC            520.0            512.0
# 9            BCN            518.0            519.0

# %%
fig, ax = plt.subplots(figsize=(14,7))
x = np.arange(len(plot_df2))
width = 0.4
p1 = plt.bar(x-0.2, plot_df2['no_of_flights_o'],width, color='grey', label='no.of outgoing flight routes')
p2 = plt.bar(x+0.2, plot_df2['no_of_flights_i'],width, color='skyblue', label='no.of incoming flight routes')

plt.bar_label(p1, label_type='edge')
plt.bar_label(p2, label_type='edge')

plt.title('Top 10 Airports with maximum connectivity', fontsize=25)
plt.xlabel('Airport_IATA_codes', fontsize=20)
plt.xticks(plot_df2.index, plot_df2['Airport_Name_s'], fontsize=17)
plt.ylabel('no_of_routes', fontsize=20)
plt.yticks(fontsize=17)

plt.legend(frameon=False, fontsize=15)
plt.show()

# %% [markdown]
# ## VIS_3: Plotting Top 10 Airports with most connectivity

# %%
folium_df = pd.merge(left = plot_df2, 
                 right = airports,
                 how= 'left',
                 left_on='Airport_Name_s',
                 right_on='IATA',
                 suffixes=('_l', '_r'))
folium_df
# Out:
#   Airport_Name_s  no_of_flights_o  no_of_flights_i  Airport_ID  \
# 0            ATL            938.0            934.0        3682
# 1            FRA            680.0            673.0         340
# 2            CDG            589.0            580.0        1382
# 3            ORD            570.0            561.0        3830
# 4            PEK            561.0            560.0        3364
# 5            LHR            552.0            549.0         507
# 6            SIN            530.0            536.0        3316
# 7            LGW            529.0            521.0         502
# 8            MUC            520.0            512.0         346
# 9            BCN            518.0            519.0        1218
#
#                                        Airport_Name       City  \
# 0  Hartsfield Jackson Atlanta International Airport    Atlanta
# 1                         Frankfurt am Main Airport  Frankfurt
# 2           Charles de Gaulle International Airport      Paris
# 3              Chicago O'Hare International Airport    Chicago
# 4             Beijing Capital International Airport    Beijing
# 5                           London Heathrow Airport     London
# 6                          Singapore Changi Airport  Singapore
# 7                            London Gatwick Airport     London
# 8                                    Munich Airport     Munich
# 9                   Barcelona International Airport  Barcelona
#
#           Country IATA  ICAO   Latitude   Longitude  Altitude  Timezone DST  \
# 0   United States  ATL  KATL  33.636700  -84.428101      1026      -5.0   A
# 1         Germany  FRA  EDDF  50.033333    8.570556       364       1.0   E
# 2          France  CDG  LFPG  49.012798    2.550000       392       1.0   E
# 3   United States  ORD  KORD  41.978600  -87.904800       672      -6.0   A
# 4           China  PEK  ZBAA  40.080101  116.584999       116       8.0   U
# 5  United Kingdom  LHR  EGLL  51.470600   -0.461941        83       0.0   E
# 6       Singapore  SIN  WSSS   1.350190  103.994003        22       8.0   N
# 7  United Kingdom  LGW  EGKK  51.148102   -0.190278       202       0.0   E
# 8         Germany  MUC  EDDM  48.353802   11.786100      1487       1.0   E
# 9           Spain  BCN  LEBL  41.297100    2.078460        12       1.0   E
#
#   Tz database time zone     Type       Source
# 0      America/New_York  airport  OurAirports
# 1         Europe/Berlin  airport  OurAirports
# 2          Europe/Paris  airport  OurAirports
# 3       America/Chicago  airport  OurAirports
# 4         Asia/Shanghai  airport  OurAirports
# 5         Europe/London  airport  OurAirports
# 6        Asia/Singapore  airport  OurAirports
# 7         Europe/London  airport  OurAirports
# 8         Europe/Berlin  airport  OurAirports
# 9         Europe/Madrid  airport  OurAirports

# %%
import folium


for i in range(0,len(folium_df)):
   folium.Marker(
      location=[folium_df.iloc[i]['Latitude'], folium_df.iloc[i]['Longitude']],
      popup=folium_df.iloc[i]['Airport_Name'],
   ).add_to(map_1)

map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_359f4007ef788228784650537d9afacd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_359f4007ef788228784650537d9afacd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_359f4007ef788228784650537d9afacd = L.map(
#                 &quot;map_359f4007ef788228784650537d9afacd&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6db11e3b4f2036288be73337030c6e97 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_359f4007ef788228784650537d9afacd);
#
#
#             var marker_410076b88c47fbcec1f80e0c6b29d97d = L.marker(
#                 [33.6367, -84.428101],
#                 {}
#             ).addTo(map_359f4007ef788228784650537d9afacd);
#
#
#         var popup_1453001f55ad0980c19d5f0285b17c74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d769f26055522b8fab4668a0551c0a1 = $(`&lt;div id=&quot;html_2d769f26055522b8fab4668a0551c0a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATL&lt;/div&gt;`)[0];
#                 popup_1453001f55ad0980c19d5f0285b17c74.setContent(html_2d769f26055522b8fab4668a0551c0a1);
#
#
#
#         marker_410076b88c47fbcec1f80e0c6b29d97d.bindPopup(popup_1453001f55ad0980c19d5f0285b17c74)
#         ;
#
#
#
#
#             var marker_39bfef4253f17de9c1e761b5b1da3e22 = L.marker(
#                 [50.033333, 8.570556],
#                 {}
#             ).addTo(map_359f4007ef788228784650537d9afacd);
#
#
#         var popup_1159f3d63732e8ffe0f17fb94f429b6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7779eea5da0dde029cd1decb1ddcc3b5 = $(`&lt;div id=&quot;html_7779eea5da0dde029cd1decb1ddcc3b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FRA&lt;/div&gt;`)[0];
#                 popup_1159f3d63732e8ffe0f17fb94f429b6a.setContent(html_7779eea5da0dde029cd1decb1ddcc3b5);
#
#
#
#         marker_39bfef4253f17de9c1e761b5b1da3e22.bindPopup(popup_1159f3d63732e8ffe0f17fb94f429b6a)
#         ;
#
#
#
#
#             var marker_404c58ea51e9d712e10b4df2a80af988 = L.marker(
#                 [49.012798, 2.55],
#                 {}
#             ).addTo(map_359f4007ef788228784650537d9afacd);
#
#
#         var popup_c2d4be5d97ed140b7ccb1f40aa41d23e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d031997baa4f6e96dfab159f42a7a7c1 = $(`&lt;div id=&quot;html_d031997baa4f6e96dfab159f42a7a7c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CDG&lt;/div&gt;`)[0];
#                 popup_c2d4be5d97ed140b7ccb1f40aa41d23e.setContent(html_d031997baa4f6e96dfab159f42a7a7c1);
#
#
#
#         marker_404c58ea51e9d712e10b4df2a80af988.bindPopup(popup_c2d4be5d97ed140b7ccb1f40aa41d23e)
#         ;
#
#
#
#
#             var marker_3738423744f58b35e6e75861ec1740ca = L.marker(
#                 [41.9786, -87.9048],
#                 {}
#             ).addTo(map_359f4007ef788228784650537d9afacd);
#
#
#         var popup_12b44d0ebdc14ffc3ef14cc1ab47fdde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a445f352a2d4c758aa0ed942b97fbe9 = $(`&lt;div id=&quot;html_2a445f352a2d4c758aa0ed942b97fbe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ORD&lt;/div&gt;`)[0];
#                 popup_12b44d0ebdc14ffc3ef14cc1ab47fdde.setContent(html_2a445f352a2d4c758aa0ed942b97fbe9);
#
#
#
#         marker_3738423744f58b35e6e75861ec1740ca.bindPopup(popup_12b44d0ebdc14ffc3ef14cc1ab47fdde)
#         ;
#
#
#
#
#             var marker_eb965cab58002a0c471931e9baab02ff = L.marker(
#                 [40.0801010131836, 116.584999084473],
#                 {}
#             ).addTo(map_359f4007ef788228784650537d9afacd);
#
#
#         var popup_ea6a7a550ca2c7c9e74e1c0d87ad80c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_187cf48d10a54a393531e066805e5f91 = $(`&lt;div id=&quot;html_187cf48d10a54a393531e066805e5f91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PEK&lt;/div&gt;`)[0];
#                 popup_ea6a7a550ca2c7c9e74e1c0d87ad80c0.setContent(html_187cf48d10a54a393531e066805e5f91);
#
#
#
#         marker_eb965cab58002a0c471931e9baab02ff.bindPopup(popup_ea6a7a550ca2c7c9e74e1c0d87ad80c0)
#         ;
#
#
#
#
#             var marker_5117678d36c21bd99ba1fce73fc17993 = L.marker(
#                 [51.4706, -0.461941],
#                 {}
#             ).addTo(map_359f4007ef788228784650537d9afacd);
#
#
#         var popup_61720cce3525d6969fa351e41fdc7a17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ## VIS_4: Planes that fly the most amount of routes

# %%
final_routes['Equipment'].value_counts()

# %%
plot_df4 = (
    final_routes['Equipment'].value_counts()
        .head(10)
        .rename_axis('Plane')
        .reset_index(name='no_of_routes')
)
plt.figure(figsize=(14,7))
y=  final_routes['Equipment'].value_counts().head(10)
mylabels = plot_df4['Plane']

plt.title('Planes that fly the most amount of routes', fontsize=25)

pie = plt.pie(y,autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.legend( loc = 'right', labels=mylabels)
plt.show()

# %% [markdown]
# ## Cities with most connectivity

# %%
plot_df5 = (
    final_routes['City_s'].value_counts()
        .rename_axis('City_Name_s')
        .reset_index(name='no_of_flights_o')
)
plot_df5.info()

plot_df6 = (
    final_routes['City_d'].value_counts()
        .rename_axis('City_Name_d')
        .reset_index(name='no_of_flights_i')
)
plot_df6.info()



plot_df7 = pd.merge(left = plot_df5, 
                 right = plot_df6,
                 how= 'outer',
                 left_on='City_Name_s',
                 right_on='City_Name_d',
                 suffixes=('_x', '_y'))

plot_df7 = plot_df7.head(10)
plot_df7.drop(['City_Name_d'], axis=1, inplace = True)
plot_df7

# %%
fig, ax = plt.subplots(figsize=(14,7))
x = np.arange(len(plot_df2))
width = 0.4
p1 = plt.bar(x-0.2, plot_df7['no_of_flights_o'],width, color='skyblue', label='no.of outgoing flight routes')
p2 = plt.bar(x+0.2, plot_df7['no_of_flights_i'],width, color='pink', label='no.of incoming flight routes')

plt.bar_label(p1, label_type='edge')
plt.bar_label(p2, label_type='edge')

plt.title('Top 10 Cities with maximum connectivity', fontsize=25)
plt.xlabel('Cities', fontsize=20)
plt.xticks(plot_df7.index, plot_df7['City_Name_s'], fontsize=17)
plt.ylabel('no_of_routes', fontsize=20)
plt.yticks(fontsize=17)

plt.legend(frameon=False, fontsize=15)
plt.show()
